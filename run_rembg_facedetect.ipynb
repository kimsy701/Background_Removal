# %%
#when using google colab, run this code
"""
from google.colab import drive
drive.mount('/content/drive')
"""
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/rembg_facedetect')

# %%
# !python u2net_human_seg_test.py
# Out:
# ['/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/19035828_web1__12294096_web1_180615-PNR-newmayorchallenge.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/2019-LADIES-NIGHT-2ND-GOMES.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/Athlete-Intake.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/480112-637286191695715805-16x9.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/coach-yelling-at-athlete-716268.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/5-mental-skills-of-successful-athletes-image.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/Two_dancers.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/images (2).jpeg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images/image1440x560cropped.jpg', '/content/drive/MyDrive/rembg_facedetect/test_data/test_human_images
# ...
