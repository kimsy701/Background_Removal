# %%
#when using google colab, run this code
"""
from google.colab import drive
drive.mount('/content/drive')
"""
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/rembg-main')

# %%
#run this code in ipynb cell, or run this code in cmd(in cmd, without "!")
# !pip install rembg[gpu] # for library
# !pip install rembg[gpu,cli] # for library + cli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 MB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 55.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
#예시 : %run test.py

# %%
#run this code in ipynb cell, or run this code in cmd(in cmd, without "!")
#not with alpha matting
# !rembg p ft_test_input ft_test_output #default model : u2net
# Out:
# 100% 42/42 [01:22<00:00,  1.96s/it]

# %%
#run this code in ipynb cell, or run this code in cmd(in cmd, without "!")
#with alphamatting
# !rembg p -a ft_test_input ft_test_output_alpha #default model : u2net
# Out:
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 704GB/s]
#  29% 12/42 [00:41<01:39,  3.31s/it]PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#  45% 19/42 [01:04<01:10,  3.06s/it]PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#  86% 36/42 [01:59<00:19,  3.30s/it]PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# ...
