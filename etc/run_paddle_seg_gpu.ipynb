# %%
# !nvidia-smi
# Out:
# Fri Dec 15 09:39:22 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !which python #view python location
# !python --version #view the python version
# Out:
# /usr/local/bin/python
# Python 3.10.12

# %%
# !python -m pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !python -c “import platform;print(platform.architecture()[0]);print(platform.machine())”
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `platform.architecture'
# /bin/bash: -c: line 1: `python -c “import platform;print(platform.architecture()[0]);print(platform.machine())”'

# %%
# !python -m pip install paddlepaddle-gpu==2.5.2.post120 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# ...

# %%
import paddle

# %%
#!pip install pyyaml >= 5.1
# !pip install pyyaml
#!pip install visualdl >= 2.2.0
# !pip install visualdl
# !pip install opencv-python <= 4.6.0
# !pip install tqdm
# !pip install filelock
# !pip install scipy
# !pip install prettytable
# !pip install scikit-learn
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement 4.6.0 (from versions: none)
# ERROR: No matching distribution found for 4.6.0
# ...

# %%
# !git clone https://github.com/PaddlePaddle/PaddleSeg
# !cd /content/PaddleSeg
# !pip install -r /content/PaddleSeg/requirements.txt
# !pip install -v -e .
# Out:
# fatal: destination path 'PaddleSeg' already exists and is not an empty directory.
# ...
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !sh /content/PaddleSeg/tests/install/check_predict.sh
# Out:
# 2023-12-17 06:14:40 [WARNING]	Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# 2023-12-17 06:14:40 [INFO]
# ------------Environment Information-------------
# platform: Linux-6.1.58+-x86_64-with-glibc2.35
# Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.2.r12.2/compiler.33191640_0
# cudnn: 8.9
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PaddleSeg: 2.9.0
# PaddlePaddle: 2.5.2
# OpenCV: 4.5.5
# ------------------------------------------------
# 2023-12-17 06:14:40 [INFO]
# ---------------Config Information---------------
# batch_size: 4
# iters: 1000
# train_dataset:
#   dataset_root: data/optic_disc_seg
#   mode: train
#   num_classes: 2
#   train_path: data/optic_disc_seg/train_list.txt
#   transforms:
#   - max_scale_factor: 2.0
# ...
